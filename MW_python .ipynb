# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('MW.csv')

# %%
df.head()
# Out:
#   INSTRUMENT TYPE \n  SYMBOL \n EXPIRY DATE \n OPTION TYPE \n STRIKE PRICE \n  \
# 0      Index Options  BANKNIFTY    16-Jul-2020            Put       22,000.00
# 1      Index Options  BANKNIFTY    16-Jul-2020           Call       23,000.00
# 2      Index Options  BANKNIFTY    16-Jul-2020            Put       22,500.00
# 3      Index Options  BANKNIFTY    16-Jul-2020           Call       23,500.00
# 4      Index Options      NIFTY    16-Jul-2020            Put       10,700.00
#
#   LAST PRICE \n  CHNG \n  %CHNG \n  VOLUME \n(Contracts)         VALUE   \
# 0        172.20    26.45     18.15                 11823  50,367,242.00
# 1        303.55   -97.35    -24.28                 11326  79,134,452.80
# 2        338.85    61.35     22.11                  9991  86,919,961.40
# 3        143.25   -61.35    -29.99                  9821  38,085,546.40
# 4         88.05    11.65     15.25                  9545  84,011,382.00
#
#    OPEN INTEREST \n UNDERLYING VALUE \n
# ...

# %%
df.describe()
# Out:
#           CHNG \n   %CHNG \n  VOLUME \n(Contracts)  OPEN INTEREST \n
# count   20.000000  20.000000             20.000000         20.000000
# mean   -17.597500  -5.836000           6960.300000      25002.900000
# std     51.886405  19.793253           2536.935348      32623.995541
# min   -188.100000 -34.230000           3345.000000      10444.000000
# 25%    -23.637500 -25.027500           4956.000000      13216.750000
# 50%     -5.250000  -0.630000           6559.500000      15651.000000
# 75%      7.287500  13.450000           8798.750000      18965.000000
# max     61.350000  22.110000          11823.000000     155936.000000

# %%
values = df[['SYMBOL \n','CHNG \n']]
print(values)
# Out:
#     SYMBOL \n  CHNG \n
# 0   BANKNIFTY    26.45
# 1   BANKNIFTY   -97.35
# 2   BANKNIFTY    61.35
# 3   BANKNIFTY   -61.35
# 4       NIFTY    11.65
# 5       NIFTY   -10.55
# 6   BANKNIFTY   -31.10
# 7       NIFTY   -21.15
# 8   BANKNIFTY     7.40
# 9       NIFTY    17.60
# 10  BANKNIFTY  -188.10
# 11      NIFTY   -16.55
# 12      NIFTY    -6.75
# 13      NIFTY     7.25
# 14      NIFTY   -41.55
# 15        TCS    -9.75
# 16      NIFTY     4.30
# 17      NIFTY    -1.90
# 18      NIFTY    -3.75
# 19      NIFTY     1.90

# %%
ax = values.plot.bar(x='SYMBOL \n', y='CHNG \n', rot=0)
plt.show()
